# %%
import sys

from pyspark.sql import SparkSession
from pyspark.sql.functions import count
from pyspark.sql.functions import max, min, col

import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import matplotlib.colors as mcolors
import altair as alt

import numpy as np
import pandas as pd

from graphframes import *
from pyspark.sql.types import *
from graphframes import *

import networkx as nx

# %%
# Load external packages programatically 
# Here, we assume that you use Spark 3.0.1 or later (compiled against Scala 2.12)
import os
packages = "graphframes:graphframes:0.8.1-spark3.0-s_2.12"
# jars = "graphframes-0.3.0-spark2.0-s_2.11.jar"

os.environ["PYSPARK_SUBMIT_ARGS"] = (
    "--repositories https://repos.spark-packages.org/ --packages {0} pyspark-shell".format(packages)
)
#os.environ["PYSPARK_SUBMIT_ARGS"] = (
#    "--packages {0} --jars {1} pyspark-shell".format(packages, jars)
#)

# %%
spark = (SparkSession     
         .builder     
         .appName("Stackoverflow")     
         .getOrCreate())

# %%
stack_nodes_df = (spark.read.format("csv")      
          .option("header", "true")      
          .option("inferSchema", "true")      
          .load("../data/stack_network_nodes.csv"))

# %%
stack_links_df = (spark.read.format("csv")      
          .option("header", "true")      
          .option("inferSchema", "true")      
          .load("../data/stack_network_links.csv"))

# %%
count_stack_df_1 = (stack_nodes_df     
                .select(col("id").alias("PopularTopic"), "nodesize")      
                .groupBy("PopularTopic")      
                .agg(max("nodesize").alias("nodesize"))      
                .orderBy("nodesize", ascending=False))

# %%
count_stack_df_1.show(n=60, truncate=False)   
print("Total Rows = %d" % (count_stack_df_1.count()))
# Out:
# +-------------------+--------+
# |PopularTopic       |nodesize|
# +-------------------+--------+
# |javascript         |649.16  |
# |java               |610.65  |
# |python             |438.67  |
# |php                |361.22  |
# |css                |341.17  |
# |c#                 |321.13  |
# |html               |272.45  |
# |c++                |268.11  |
# |android            |229.86  |
# |jquery             |208.29  |
# |c                  |189.83  |
# |mysql              |165.43  |
# |sql                |154.23  |
# |html5              |140.18  |
# |asp.net            |129.55  |
# |angularjs          |126.59  |
# |node.js            |117.36  |
# |linux              |108.54  |
# |ios                |87.46   |
# |.net               |75.08   |
# |ruby               |70.14   |
# |sql-server         |64.62   |
# |swift              |63.62   |
# |reactjs            |59.03   |
# |ruby-on-rails      |55.31   |
# |git                |54.48   |
# |spring             |52.84   |
# |r                  |52.7    |
# |mongodb            |50.95   |
# |objective-c        |47.01   |
# |wordpress          |46.74   |
# |machine-learning   |44.21   |
# |django             |40.91   |
# |postgresql         |39.03   |
# |ajax               |35.41   |
# |laravel            |32.12   |
# |twitter-bootstrap  |31.05   |
# |sass               |30.55   |
# |oracle             |30.19   |
# |amazon-web-services|30.05   |
# |hibernate          |29.83   |
# |angular            |29.09   |
# |matlab             |27.21   |
# |rest               |27.08   |
# |scala              |27.02   |
# |json               |25.38   |
# |go                 |24.84   |
# |bash               |23.91   |
# |xml                |23.77   |
# |vb.net             |23.56   |
# |docker             |22.85   |
# |java-ee            |22.45   |
# |windows            |19.71   |
# |perl               |19.38   |
# |wpf                |19.38   |
# |unity3d            |19.36   |
# |web-services       |18.94   |
# |angular2           |18.79   |
# |codeigniter        |18.71   |
# |visual-studio      |18.13   |
# +-------------------+--------+
# only showing top 60 rows
#
# Total Rows = 115

# %%
count_stack_df_2 = (stack_nodes_df     
                .select(col("id").alias("LessPopularTopic"), "nodesize")      
                .groupBy("LessPopularTopic")      
                .agg(min("nodesize").alias("nodesize"))      
                .orderBy("nodesize", ascending=True))
print("Total Rows = %d" % (count_stack_df_2.count()))
# Out:
# Total Rows = 115

# %%
count_stack_df_2.show(n=60, truncate=False)   
print("Total Rows = %d" % (count_stack_df_2.count()))
# Out:
# +-------------------+--------+
# |LessPopularTopic   |nodesize|
# +-------------------+--------+
# |drupal             |8.25    |
# |linq               |8.32    |
# |vue.js             |8.38    |
# |ionic-framework    |8.44    |
# |redux              |8.52    |
# |api                |8.61    |
# |testing            |8.95    |
# |flask              |9.39    |
# |tdd                |9.45    |
# |regex              |9.46    |
# |nginx              |9.49    |
# |less               |9.73    |
# |devops             |9.81    |
# |powershell         |9.85    |
# |jenkins            |10.02   |
# |twitter-bootstrap-3|10.13   |
# |maven              |10.3    |
# |plsql              |10.32   |
# |qt                 |10.53   |
# |cloud              |10.66   |
# |elasticsearch      |10.82   |
# |mvc                |10.92   |
# |apache-spark       |11.04   |
# |xamarin            |11.18   |
# |haskell            |11.18   |
# |asp.net-web-api    |11.28   |
# |xcode              |11.37   |
# |excel-vba          |11.38   |
# |eclipse            |11.39   |
# |shell              |11.63   |
# |ubuntu             |11.98   |
# |agile              |12.22   |
# |spring-boot        |12.37   |
# |excel              |12.5    |
# |osx                |12.58   |
# |photoshop          |12.62   |
# |selenium           |12.7    |
# |github             |12.71   |
# |wcf                |12.73   |
# |entity-framework   |12.88   |
# |apache             |13.17   |
# |embedded           |13.27   |
# |bootstrap          |13.28   |
# |react-native       |13.61   |
# |azure              |13.68   |
# |jsp                |13.78   |
# |redis              |13.85   |
# |express            |14.27   |
# |android-studio     |14.79   |
# |iphone             |15.29   |
# |unix               |15.67   |
# |vba                |16.87   |
# |typescript         |17.53   |
# |hadoop             |17.95   |
# |spring-mvc         |18.0    |
# |visual-studio      |18.13   |
# |codeigniter        |18.71   |
# |angular2           |18.79   |
# |web-services       |18.94   |
# |unity3d            |19.36   |
# +-------------------+--------+
# only showing top 60 rows
#
# Total Rows = 115

# %%
df_nodes = pd.read_csv('../data/stack_network_nodes.csv', header=None)

# %%
df_nodes.head()
# Out:
#            0      1         2
# 0         id  group  nodesize
# 1       html      6    272.45
# 2        css      6    341.17
# 3  hibernate      8     29.83
# 4     spring      8     52.84

# %%
df_links = pd.read_csv('../data/stack_network_links.csv', header=None)

# %%
df_links.head()
# Out:
#     0                 1     2                   3
# 0  id               src   dst               value
# 1   1             azure  .net  20.933192346640457
# 2   2        sql-server  .net  32.322524219339904
# 3   3           asp.net  .net   48.40702996199019
# 4   4  entity-framework  .net   24.37090250532431

# %%
def create_stackoverflow_graph():
    nodes = spark.read.csv("../data/stack_network_nodes.csv", header=True)
    relationships = spark.read.csv("../data/stack_network_links.csv", header=True)
    return GraphFrame(nodes, relationships)

# %%
g = create_stackoverflow_graph()

# %%
print(g)
# Out:
# GraphFrame(v:[id: string, group: string ... 1 more field], e:[src: string, dst: string ... 2 more fields])

# %%
gpvertices = g.vertices.toPandas()

# %%
g.vertices.show()
# Out:
# +-------------+-----+--------+
# |           id|group|nodesize|
# +-------------+-----+--------+
# |         html|    6|  272.45|
# |          css|    6|  341.17|
# |    hibernate|    8|   29.83|
# |       spring|    8|   52.84|
# |         ruby|    3|   70.14|
# |ruby-on-rails|    3|   55.31|
# |          ios|    4|   87.46|
# |        swift|    4|   63.62|
# |        html5|    6|  140.18|
# |            c|    1|  189.83|
# |          c++|    1|  268.11|
# |      asp.net|    2|  129.55|
# |           c#|    2|  321.13|
# |  objective-c|    4|   47.01|
# |   javascript|    6|  649.16|
# |       jquery|    6|  208.29|
# |        redux|    3|    8.52|
# |      reactjs|    3|   59.03|
# |          php|    6|  361.22|
# |        mysql|    6|  165.43|
# +-------------+-----+--------+
# only showing top 20 rows

# %%
g.edges.show()
# Out:
# +---+----------------+-------------------+------------------+
# | id|             src|                dst|             value|
# +---+----------------+-------------------+------------------+
# |  1|           azure|               .net|20.933192346640457|
# |  2|      sql-server|               .net|32.322524219339904|
# |  3|         asp.net|               .net| 48.40702996199019|
# |  4|entity-framework|               .net| 24.37090250532431|
# |  5|             wpf|               .net| 32.35092522005943|
# |  6|            linq|               .net|20.501743858149066|
# |  7|             wcf|               .net|28.074400427611113|
# |  8|              c#|               .net|62.167895042923824|
# |  9|             tdd|              agile|37.146589924204555|
# | 10|     codeigniter|               ajax| 23.19190040565183|
# | 11|          jquery|               ajax| 50.56672861589973|
# | 12|           mysql|               ajax| 24.80008942291756|
# | 13|             css|               ajax|26.613713724688935|
# | 14|             php|               ajax| 28.01067925660409|
# | 15|      javascript|               ajax| 24.39914442262329|
# | 16|            json|               ajax| 32.94744601093195|
# | 17|           cloud|amazon-web-services| 21.31860679884144|
# | 18|           azure|amazon-web-services| 21.30994959394633|
# | 19|          devops|amazon-web-services| 24.98353120101788|
# | 20|          docker|amazon-web-services|32.198071014100535|
# +---+----------------+-------------------+------------------+
# only showing top 20 rows

# %%
G = nx.Graph()
df_nodes = pd.read_csv('../data/stack_network_nodes.csv')
df_edges = pd.read_csv('../data/stack_network_links2.csv')

for index, row in df_nodes.iterrows():
    G.add_node(row["id"], name=row["id"], group=row["group"], nodesize=row["nodesize"])
    
for index, row in df_edges.iterrows():
    G.add_weighted_edges_from([(row["source"], row["target"], row["value"])])

# %%
def show_graph(G):
    color_map = {1:'#f09494', 2:'#eebcbc', 3:'#72bbd0', 4:'#91f0a1', 5:'#629fff', 6:'#bcc2f2',  
                 7:'#eebcbc', 8:'#F5B041', 9:'#F54C41', 10:'#caf3a6', 11:'#ffdf55', 12:'#ef77aa', 
                 13:'#d6dcff', 14:'#d2f5f0'} 

    plt.figure(figsize=(25,25))
    options = {
        'edge_color': '#F9E79F',
        'width': 1,
        'with_labels': True,
        'font_weight': 'regular',
    }

    colors = [color_map[G.nodes[node]['group']] for node in G]
    sizes = [G.nodes[node]['nodesize']*10 for node in G]

    nx.draw(G, node_color=colors, node_size=sizes, pos=nx.spring_layout(G, k=0.80, iterations=50), **options)
    ax = plt.gca()
    ax.collections[0].set_edgecolor("#555555") 
    plt.show()

# %%
show_graph(G)

# %%
g.inDegrees.show()
# Out:
# +----------------+--------+
# |              id|inDegree|
# +----------------+--------+
# |              qt|       1|
# |          iphone|       4|
# |            unix|       1|
# |          devops|       3|
# |        embedded|       1|
# |           azure|       5|
# |           xcode|       4|
# |         android|       3|
# |        angular2|       2|
# |       bootstrap|       2|
# |      postgresql|       6|
# |         angular|       1|
# |         haskell|       1|
# |      powershell|       1|
# |machine-learning|       2|
# |           redux|       4|
# |             osx|       4|
# |          ubuntu|       1|
# |         node.js|       7|
# |              c#|      14|
# +----------------+--------+
# only showing top 20 rows

# %%
g.inDegrees.filter("inDegree >= 5").sort('inDegree', ascending=False).show()
# Out:
# +----------------+--------+
# |              id|inDegree|
# +----------------+--------+
# |          jquery|      16|
# |              c#|      14|
# |             css|      14|
# |         asp.net|      13|
# |       angularjs|      13|
# |           mysql|      11|
# |      javascript|      11|
# |             php|      10|
# |           linux|      10|
# |           html5|      10|
# |            sass|       9|
# |       hibernate|       9|
# |          spring|       9|
# |      sql-server|       9|
# |            java|       8|
# |            .net|       8|
# |             wcf|       8|
# |         reactjs|       8|
# |         mongodb|       8|
# |entity-framework|       8|
# +----------------+--------+
# only showing top 20 rows

# %%
gindegrees = g.inDegrees.sort('inDegree', ascending=False).toPandas()

# %%
bars = alt.Chart(gindegrees).mark_bar().encode(
    x='inDegree:Q',
    y=alt.Y('id:O', sort='-x')
)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3 # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='inDegree'
)

(bars + text).properties(height=1100)
# Out:
# alt.LayerChart(...)

# %%
results = g.pageRank(resetProbability=0.15, tol=0.01)
results.edges.select("src", "dst", "weight").show()
# Out:
# +-----------------+---------------+-------------------+
# |              src|            dst|             weight|
# +-----------------+---------------+-------------------+
# |          java-ee|           java|               0.25|
# |             json|         jquery|               0.25|
# |            html5|     javascript| 0.1111111111111111|
# |            html5|            php| 0.1111111111111111|
# |              wcf|            wpf|              0.125|
# |          asp.net|            wpf|0.07692307692307693|
# |       typescript|        angular|                0.5|
# |        angularjs|asp.net-web-api|0.07692307692307693|
# |          java-ee|      hibernate|               0.25|
# |          node.js|        reactjs|0.14285714285714285|
# |             java|     spring-mvc|              0.125|
# |              php|            css|                0.1|
# |           iphone|          xcode|               0.25|
# |             .net|          azure|              0.125|
# |twitter-bootstrap|          html5|0.16666666666666666|
# |            linux|            git|                0.1|
# |        wordpress|    codeigniter|0.16666666666666666|
# |             java|        android|              0.125|
# |          java-ee|     spring-mvc|               0.25|
# |             .net|           linq|              0.125|
# +-----------------+---------------+-------------------+
# only showing top 20 rows

# %%
results = g.pageRank(resetProbability=0.15, tol=0.01)
results.vertices.select("id", "PageRank").sort('PageRank', ascending=False).show()
# Out:
# +----------+------------------+
# |        id|          PageRank|
# +----------+------------------+
# |     linux|2.7906672644518746|
# |    jquery| 2.513724545860744|
# |        c#|2.4128014355226903|
# | angularjs| 2.213680026434017|
# |       css|2.1846395469526954|
# |   asp.net| 2.100635920912717|
# |    python| 2.008879367714944|
# |    spring|1.9087774565460358|
# | hibernate|1.8895818021232351|
# |     mysql|1.8751825228493302|
# |      java|1.8475503880440314|
# |javascript|1.7005993746855077|
# |       php|1.6036981533751555|
# |     html5|1.5504734066180004|
# |   mongodb|1.5167378169235708|
# |spring-mvc|1.4975603921717482|
# |     scala| 1.493967459332789|
# |       ios|1.4852062566919497|
# |sql-server|1.4592884505464236|
# |postgresql| 1.437945422455678|
# +----------+------------------+
# only showing top 20 rows

# %%
gpagerank = results.vertices.select("id", "PageRank").sort('PageRank', ascending=False).toPandas()

# %%
bars = alt.Chart(gpagerank).mark_bar().encode(
    x='PageRank:Q',
    y=alt.Y('id:O', sort='-x')
)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3 # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='PageRank'
)

(bars + text).properties(height=1500)
# Out:
# alt.LayerChart(...)

# %%
results = g.shortestPaths(landmarks=["java", "python"])
results.select("id", "distances").show()
# Out:
# +----------------+--------------------+
# |              id|           distances|
# +----------------+--------------------+
# |           plsql|[java -> 7, pytho...|
# |      postgresql|[java -> 4, pytho...|
# |              go|[java -> 5, pytho...|
# |   visual-studio|[java -> 7, pytho...|
# |              qt|[java -> 2, pytho...|
# |     spring-boot|[java -> 2, pytho...|
# |           scala|                  []|
# |               r|[java -> 3, pytho...|
# |entity-framework|[java -> 6, pytho...|
# |            ajax|[java -> 4, pytho...|
# |           maven|[java -> 2, pytho...|
# |          ubuntu|[java -> 4, pytho...|
# |            html|[java -> 5, pytho...|
# |             wcf|[java -> 6, pytho...|
# |         asp.net|[java -> 5, pytho...|
# |          iphone|[java -> 3, pytho...|
# |       wordpress|[java -> 5, pytho...|
# |           html5|[java -> 5, pytho...|
# |             vba|                  []|
# |          oracle|[java -> 7, pytho...|
# +----------------+--------------------+
# only showing top 20 rows

# %%
total_degree = g.degrees
in_degree = g.inDegrees
out_degree = g.outDegrees
(total_degree.join(in_degree, "id", how="left")
.join(out_degree, "id", how="left")
.fillna(0)
.sort("inDegree", ascending=False)
.show())
# Out:
# +----------------+------+--------+---------+
# |              id|degree|inDegree|outDegree|
# +----------------+------+--------+---------+
# |          jquery|    32|      16|       16|
# |             css|    27|      14|       13|
# |              c#|    28|      14|       14|
# |         asp.net|    26|      13|       13|
# |       angularjs|    26|      13|       13|
# |      javascript|    24|      11|       13|
# |           mysql|    22|      11|       11|
# |           linux|    20|      10|       10|
# |           html5|    19|      10|        9|
# |             php|    20|      10|       10|
# |      sql-server|    18|       9|        9|
# |       hibernate|    17|       9|        8|
# |            sass|    18|       9|        9|
# |          spring|    18|       9|        9|
# |entity-framework|    16|       8|        8|
# |            .net|    16|       8|        8|
# |            java|    16|       8|        8|
# |             wcf|    16|       8|        8|
# |         reactjs|    16|       8|        8|
# |         mongodb|    16|       8|        8|
# +----------------+------+--------+---------+
# only showing top 20 rows

# %%
degree_centrality = nx.degree_centrality(G)
sorted_degree_centrality = sorted(degree_centrality.items(),key=lambda x:x[1],reverse=True)
sorted_degree_centrality
# Out:
# [('jquery', 0.14035087719298245),
#  ('css', 0.12280701754385964),
#  ('c#', 0.12280701754385964),
#  ('asp.net', 0.11403508771929824),
#  ('angularjs', 0.11403508771929824),
#  ('javascript', 0.10526315789473684),
#  ('mysql', 0.09649122807017543),
#  ('html5', 0.08771929824561403),
#  ('php', 0.08771929824561403),
#  ('linux', 0.08771929824561403),
#  ('hibernate', 0.07894736842105263),
#  ('spring', 0.07894736842105263),
#  ('sass', 0.07894736842105263),
#  ('sql-server', 0.07894736842105263),
#  ('reactjs', 0.07017543859649122),
#  ('.net', 0.07017543859649122),
#  ('mongodb', 0.07017543859649122),
#  ('entity-framework', 0.07017543859649122),
#  ('wcf', 0.07017543859649122),
#  ('java', 0.07017543859649122),
#  ('spring-mvc', 0.06140350877192982),
#  ('node.js', 0.06140350877192982),
#  ('linq', 0.06140350877192982),
#  ('ajax', 0.06140350877192982),
#  ('python', 0.06140350877192982),
#  ('asp.net-web-api', 0.06140350877192982),
#  ('html', 0.05263157894736842),
#  ('ios', 0.05263157894736842),
#  ('wpf', 0.05263157894736842),
#  ('wordpress', 0.05263157894736842),
#  ('codeigniter', 0.05263157894736842),
#  ('twitter-bootstrap', 0.05263157894736842),
#  ('postgresql', 0.05263157894736842),
#  ('objective-c', 0.043859649122807015),
#  ('express', 0.043859649122807015),
#  ('maven', 0.043859649122807015),
#  ('rest', 0.043859649122807015),
#  ('sql', 0.043859649122807015),
#  ('azure', 0.043859649122807015),
#  ('swift', 0.03508771929824561),
#  ('c', 0.03508771929824561),
#  ('c++', 0.03508771929824561),
#  ('redux', 0.03508771929824561),
#  ('iphone', 0.03508771929824561),
#  ('git', 0.03508771929824561),
#  ('xcode', 0.03508771929824561),
#  ('laravel', 0.03508771929824561),
#  ('json', 0.03508771929824561),
#  ('java-ee', 0.03508771929824561),
#  ('jsp', 0.03508771929824561),
#  ('redis', 0.03508771929824561),
#  ('jenkins', 0.03508771929824561),
#  ('docker', 0.03508771929824561),
#  ('amazon-web-services', 0.03508771929824561),
#  ('osx', 0.03508771929824561),
#  ('react-native', 0.02631578947368421),
#  ('spring-boot', 0.02631578947368421),
#  ('less', 0.02631578947368421),
#  ('android', 0.02631578947368421),
#  ('scala', 0.02631578947368421),
#  ('django', 0.02631578947368421),
#  ('apache', 0.02631578947368421),
#  ('nginx', 0.02631578947368421),
#  ('bash', 0.02631578947368421),
#  ('web-services', 0.02631578947368421),
#  ('windows', 0.02631578947368421),
#  ('r', 0.02631578947368421),
#  ('vb.net', 0.02631578947368421),
#  ('devops', 0.02631578947368421),
#  ('ruby', 0.017543859649122806),
#  ('ruby-on-rails', 0.017543859649122806),
#  ('hadoop', 0.017543859649122806),
#  ('apache-spark', 0.017543859649122806),
#  ('excel', 0.017543859649122806),
#  ('excel-vba', 0.017543859649122806),
#  ('vba', 0.017543859649122806),
#  ('plsql', 0.017543859649122806),
#  ('oracle', 0.017543859649122806),
#  ('flask', 0.017543859649122806),
#  ('angular2', 0.017543859649122806),
#  ('typescript', 0.017543859649122806),
#  ('machine-learning', 0.017543859649122806),
#  ('elasticsearch', 0.017543859649122806),
#  ('shell', 0.017543859649122806),
#  ('bootstrap', 0.017543859649122806),
#  ('twitter-bootstrap-3', 0.017543859649122806),
#  ('github', 0.008771929824561403),
#  ('xml', 0.008771929824561403),
#  ('tdd', 0.008771929824561403),
#  ('agile', 0.008771929824561403),
#  ('testing', 0.008771929824561403),
#  ('selenium', 0.008771929824561403),
#  ('android-studio', 0.008771929824561403),
#  ('angular', 0.008771929824561403),
#  ('qt', 0.008771929824561403),
#  ('ubuntu', 0.008771929824561403),
#  ('ionic-framework', 0.008771929824561403),
#  ('vue.js', 0.008771929824561403),
#  ('embedded', 0.008771929824561403),
#  ('go', 0.008771929824561403),
#  ('visual-studio', 0.008771929824561403),
#  ('unix', 0.008771929824561403),
#  ('eclipse', 0.008771929824561403),
#  ('unity3d', 0.008771929824561403),
#  ('drupal', 0.008771929824561403),
#  ('xamarin', 0.008771929824561403),
#  ('mvc', 0.008771929824561403),
#  ('haskell', 0.008771929824561403),
#  ('api', 0.008771929824561403),
#  ('regex', 0.008771929824561403),
#  ('perl', 0.008771929824561403),
#  ('cloud', 0.008771929824561403),
#  ('photoshop', 0.008771929824561403),
#  ('powershell', 0.008771929824561403),
#  ('matlab', 0.008771929824561403)]

# %%
def draw(G, pos, measures, measure_name):
    
    nodes = nx.draw_networkx_nodes(G, pos, node_size=20, cmap=plt.cm.plasma, 
                                   node_color=list(measures.values()),
                                   nodelist=measures.keys())
    edges = nx.draw_networkx_edges(G, pos)

    plt.title(measure_name)
    plt.colorbar(nodes)
    plt.axis('off')
    plt.show()

# %%
pos = nx.spring_layout(G, seed=675)

# %%
draw(G, pos, nx.degree_centrality(G), 'Degree Centrality')

# %%
betweenness_centrality = nx.betweenness_centrality(G)
sorted_betweenness_centrality = sorted(betweenness_centrality.items(),key=lambda x:x[1],reverse=True)
sorted_betweenness_centrality
# Out:
# [('jquery', 0.2555399753457234),
#  ('linux', 0.20840160874161803),
#  ('mysql', 0.1976931477327379),
#  ('asp.net', 0.17406690608353667),
#  ('apache', 0.13087186063431988),
#  ('json', 0.12319763505138448),
#  ('angularjs', 0.12286762799187795),
#  ('rest', 0.11370118004957315),
#  ('python', 0.11018306022497917),
#  ('postgresql', 0.08761830339613291),
#  ('java', 0.07601405167311084),
#  ('mongodb', 0.06737252741910403),
#  ('osx', 0.06635551651853466),
#  ('jenkins', 0.05981851611101727),
#  ('django', 0.05779082240190766),
#  ('amazon-web-services', 0.056437373973470865),
#  ('c#', 0.055756579881898374),
#  ('azure', 0.05400019656985602),
#  ('asp.net-web-api', 0.053419633104008046),
#  ('hibernate', 0.053043904033657156),
#  ('spring', 0.053043904033657156),
#  ('git', 0.05177577481257034),
#  ('css', 0.04133537048548417),
#  ('maven', 0.0396335043796618),
#  ('ios', 0.038487173093600655),
#  ('android', 0.031330538736221075),
#  ('docker', 0.03081403967524135),
#  ('angular2', 0.030740568234746156),
#  ('sql', 0.030740568234746156),
#  ('c', 0.029389145071492536),
#  ('c++', 0.02938914507149253),
#  ('javascript', 0.023657465051749822),
#  ('nginx', 0.020336219698120023),
#  ('redis', 0.019747881368747684),
#  ('ajax', 0.018884826898334116),
#  ('objective-c', 0.01793199813693526),
#  ('wordpress', 0.015673894667839704),
#  ('laravel', 0.01552553951249806),
#  ('typescript', 0.01552553951249806),
#  ('windows', 0.01552553951249806),
#  ('r', 0.01552553951249806),
#  ('reactjs', 0.015409856132889657),
#  ('devops', 0.015288500162743296),
#  ('node.js', 0.012514232492177091),
#  ('php', 0.011546520113878123),
#  ('spring-mvc', 0.00745968051510669),
#  ('codeigniter', 0.007164044704799247),
#  ('html5', 0.0066522337529762365),
#  ('sass', 0.006284712428031419),
#  ('sql-server', 0.0035624458060689187),
#  ('express', 0.0035544972200771017),
#  ('.net', 0.002291495700904179),
#  ('html', 0.0011514775138436054),
#  ('bash', 0.0010945505356311132),
#  ('entity-framework', 0.0010466285487518948),
#  ('wcf', 0.0010466285487518948),
#  ('scala', 0.0003105107902499612),
#  ('redux', 5.175179837499353e-05),
#  ('linq', 2.5875899187496765e-05),
#  ('ruby', 0.0),
#  ('ruby-on-rails', 0.0),
#  ('swift', 0.0),
#  ('react-native', 0.0),
#  ('spring-boot', 0.0),
#  ('less', 0.0),
#  ('hadoop', 0.0),
#  ('apache-spark', 0.0),
#  ('iphone', 0.0),
#  ('github', 0.0),
#  ('excel', 0.0),
#  ('excel-vba', 0.0),
#  ('wpf', 0.0),
#  ('vba', 0.0),
#  ('xcode', 0.0),
#  ('plsql', 0.0),
#  ('oracle', 0.0),
#  ('xml', 0.0),
#  ('flask', 0.0),
#  ('java-ee', 0.0),
#  ('jsp', 0.0),
#  ('tdd', 0.0),
#  ('agile', 0.0),
#  ('twitter-bootstrap', 0.0),
#  ('web-services', 0.0),
#  ('testing', 0.0),
#  ('selenium', 0.0),
#  ('android-studio', 0.0),
#  ('angular', 0.0),
#  ('machine-learning', 0.0),
#  ('qt', 0.0),
#  ('ubuntu', 0.0),
#  ('ionic-framework', 0.0),
#  ('elasticsearch', 0.0),
#  ('vue.js', 0.0),
#  ('embedded', 0.0),
#  ('go', 0.0),
#  ('visual-studio', 0.0),
#  ('unix', 0.0),
#  ('eclipse', 0.0),
#  ('vb.net', 0.0),
#  ('unity3d', 0.0),
#  ('drupal', 0.0),
#  ('shell', 0.0),
#  ('bootstrap', 0.0),
#  ('xamarin', 0.0),
#  ('mvc', 0.0),
#  ('haskell', 0.0),
#  ('api', 0.0),
#  ('twitter-bootstrap-3', 0.0),
#  ('regex', 0.0),
#  ('perl', 0.0),
#  ('cloud', 0.0),
#  ('photoshop', 0.0),
#  ('powershell', 0.0),
#  ('matlab', 0.0)]

# %%
draw(G, pos, nx.betweenness_centrality(G), 'Betweeness Centrality')

# %%
closeness_centrality = nx.closeness_centrality(G)
sorted_closeness_centrality = sorted(closeness_centrality.items(),key=lambda x:x[1],reverse=True)

sorted_closeness_centrality
# Out:
# [('jquery', 0.2895872367001647),
#  ('mysql', 0.2778958265228288),
#  ('ajax', 0.2586198154345401),
#  ('css', 0.25787451337276907),
#  ('javascript', 0.2571334946561807),
#  ('angularjs', 0.2571334946561807),
#  ('apache', 0.2549357724796321),
#  ('php', 0.2513552138773901),
#  ('html', 0.2471891053600853),
#  ('asp.net', 0.24650814363733023),
#  ('json', 0.2458309234625024),
#  ('mongodb', 0.24515741408315306),
#  ('linux', 0.24515741408315306),
#  ('codeigniter', 0.24448758508292587),
#  ('postgresql', 0.23861988304093565),
#  ('html5', 0.23424726738311746),
#  ('sass', 0.23302722953216373),
#  ('twitter-bootstrap', 0.2300320209263519),
#  ('nginx', 0.22944219523166892),
#  ('django', 0.22596579833421937),
#  ('rest', 0.22539661496310046),
#  ('asp.net-web-api', 0.2248302918099268),
#  ('wordpress', 0.22426680736930044),
#  ('reactjs', 0.2237061403508772),
#  ('redis', 0.2231482696766855),
#  ('node.js', 0.22259317447848478),
#  ('bootstrap', 0.2204001382767263),
#  ('express', 0.2198586145954567),
#  ('python', 0.2198586145954567),
#  ('twitter-bootstrap-3', 0.2198586145954567),
#  ('hibernate', 0.2161411984066446),
#  ('spring', 0.2161411984066446),
#  ('laravel', 0.21562037624180933),
#  ('c#', 0.2120437349297414),
#  ('git', 0.2120437349297414),
#  ('azure', 0.2120437349297414),
#  ('sql-server', 0.2047653458589265),
#  ('osx', 0.2038324741238061),
#  ('entity-framework', 0.20336921850079745),
#  ('wcf', 0.20336921850079745),
#  ('less', 0.20290806381031945),
#  ('jenkins', 0.20290806381031945),
#  ('amazon-web-services', 0.20290806381031945),
#  ('.net', 0.20199200031681913),
#  ('elasticsearch', 0.20199200031681913),
#  ('angular2', 0.20153706337916866),
#  ('bash', 0.2006333097317284),
#  ('java', 0.20018446563836884),
#  ('photoshop', 0.20018446563836884),
#  ('ionic-framework', 0.1997376253132832),
#  ('flask', 0.19840899365931458),
#  ('docker', 0.19753301576236396),
#  ('linq', 0.1970979210139887),
#  ('sql', 0.1970979210139887),
#  ('devops', 0.1970979210139887),
#  ('wpf', 0.1966647387700019),
#  ('web-services', 0.1966647387700019),
#  ('windows', 0.1966647387700019),
#  ('vb.net', 0.1953765417911591),
#  ('mvc', 0.19326664393164336),
#  ('xml', 0.1928501209921355),
#  ('maven', 0.1928501209921355),
#  ('shell', 0.1928501209921355),
#  ('ubuntu', 0.19243538954914166),
#  ('unix', 0.19243538954914166),
#  ('c', 0.19161125511852437),
#  ('c++', 0.19161125511852437),
#  ('spring-mvc', 0.19161125511852437),
#  ('ruby', 0.18878155303871494),
#  ('ruby-on-rails', 0.18878155303871494),
#  ('java-ee', 0.18603421235000184),
#  ('jsp', 0.18603421235000184),
#  ('redux', 0.18004518338098768),
#  ('api', 0.18004518338098768),
#  ('react-native', 0.17968364686817445),
#  ('drupal', 0.17932355939950076),
#  ('ios', 0.17896491228070177),
#  ('r', 0.17754455583402953),
#  ('machine-learning', 0.17719298245614035),
#  ('spring-boot', 0.1747704221491228),
#  ('android', 0.1737523420200988),
#  ('vue.js', 0.1737523420200988),
#  ('objective-c', 0.17208164642375168),
#  ('github', 0.1714223297707871),
#  ('visual-studio', 0.1714223297707871),
#  ('unity3d', 0.1714223297707871),
#  ('xamarin', 0.1714223297707871),
#  ('cloud', 0.1654019522002789),
#  ('typescript', 0.16509678254677285),
#  ('plsql', 0.16181275974746995),
#  ('oracle', 0.16181275974746995),
#  ('go', 0.16181275974746995),
#  ('powershell', 0.16122965070333492),
#  ('eclipse', 0.1586568371282817),
#  ('qt', 0.15781738296358178),
#  ('embedded', 0.15781738296358178),
#  ('swift', 0.14988686120661787),
#  ('iphone', 0.14988686120661787),
#  ('xcode', 0.14988686120661787),
#  ('matlab', 0.14814976182177297),
#  ('android-studio', 0.14549992868349734),
#  ('angular', 0.13938077280428485),
#  ('scala', 0.02631578947368421),
#  ('hadoop', 0.019736842105263157),
#  ('apache-spark', 0.019736842105263157),
#  ('excel', 0.017543859649122806),
#  ('excel-vba', 0.017543859649122806),
#  ('vba', 0.017543859649122806),
#  ('haskell', 0.015789473684210523),
#  ('tdd', 0.008771929824561403),
#  ('agile', 0.008771929824561403),
#  ('testing', 0.008771929824561403),
#  ('selenium', 0.008771929824561403),
#  ('regex', 0.008771929824561403),
#  ('perl', 0.008771929824561403)]

# %%
draw(G, pos, nx.closeness_centrality(G), 'Closeness Centrality')

# %%
eigenvector_centrality = nx.eigenvector_centrality(G)
sorted_eigenvector_centrality = sorted(eigenvector_centrality.items(),key=lambda x:x[1],reverse=True)

sorted_eigenvector_centrality
# Out:
# [('jquery', 0.3657638453622554),
#  ('css', 0.338701180241117),
#  ('javascript', 0.32563098638889276),
#  ('html5', 0.2681052746250041),
#  ('php', 0.26530101525817973),
#  ('angularjs', 0.2652026528173442),
#  ('sass', 0.2520957761852705),
#  ('mysql', 0.239342658253863),
#  ('twitter-bootstrap', 0.20709455337131874),
#  ('html', 0.2038246927757326),
#  ('ajax', 0.19962166194538747),
#  ('wordpress', 0.16028159729147778),
#  ('codeigniter', 0.14895861770584937),
#  ('reactjs', 0.13770631051407162),
#  ('asp.net', 0.1133542478710743),
#  ('node.js', 0.11189410352446867),
#  ('mongodb', 0.1032689802929971),
#  ('less', 0.09797510969685971),
#  ('bootstrap', 0.08035855855730212),
#  ('asp.net-web-api', 0.07857086259618636),
#  ('c#', 0.07728807819558778),
#  ('laravel', 0.0755393996423041),
#  ('express', 0.07516052680941876),
#  ('twitter-bootstrap-3', 0.07230568206070488),
#  ('json', 0.06629110836596808),
#  ('sql-server', 0.06557121653546155),
#  ('entity-framework', 0.06459773471227317),
#  ('wcf', 0.06459773471227316),
#  ('.net', 0.06045668795353789),
#  ('linq', 0.05655221134189457),
#  ('wpf', 0.049837531352597296),
#  ('postgresql', 0.04309792181052009),
#  ('redux', 0.0408245409431785),
#  ('photoshop', 0.03863568923087712),
#  ('azure', 0.03812899563332348),
#  ('react-native', 0.03312881575674071),
#  ('angular2', 0.030655958625378576),
#  ('ionic-framework', 0.030251802433035303),
#  ('sql', 0.030114646630457133),
#  ('vb.net', 0.029229768137510808),
#  ('apache', 0.02849688798038865),
#  ('redis', 0.018963251490500065),
#  ('drupal', 0.018283345700871704),
#  ('elasticsearch', 0.013943046633025714),
#  ('mvc', 0.012931539003135418),
#  ('visual-studio', 0.008817489324059579),
#  ('unity3d', 0.008817489324059579),
#  ('xamarin', 0.008817489324059579),
#  ('vue.js', 0.008616779932857522),
#  ('rest', 0.008194858254038736),
#  ('xml', 0.007561847042510082),
#  ('nginx', 0.005932145896088732),
#  ('ruby', 0.005549173499812795),
#  ('ruby-on-rails', 0.005549173499812795),
#  ('django', 0.005146384418846381),
#  ('amazon-web-services', 0.004551941512382314),
#  ('linux', 0.004544306379667016),
#  ('plsql', 0.0038780771023397397),
#  ('oracle', 0.0038780771023397397),
#  ('typescript', 0.003543041599398071),
#  ('hibernate', 0.0016514855917591996),
#  ('spring', 0.0016514855917591996),
#  ('web-services', 0.001311559246880594),
#  ('python', 0.0012845301070645678),
#  ('api', 0.0009347892126549791),
#  ('flask', 0.0007335733686381082),
#  ('spring-mvc', 0.0006781187877182932),
#  ('bash', 0.0006582236426079314),
#  ('java', 0.000641609645080345),
#  ('git', 0.000632597796490811),
#  ('docker', 0.0006293872535863196),
#  ('devops', 0.000622033913788417),
#  ('osx', 0.000607867802525135),
#  ('windows', 0.0005954554628817006),
#  ('shell', 0.0005934515968399274),
#  ('java-ee', 0.0005273112880151523),
#  ('jsp', 0.0005273112880151523),
#  ('cloud', 0.0005193135573213445),
#  ('ubuntu', 0.0005183682062948997),
#  ('unix', 0.0005183682062948997),
#  ('maven', 0.0004914323882165975),
#  ('spring-boot', 0.0004541229889058519),
#  ('angular', 0.0004041561923432671),
#  ('jenkins', 0.0002709907342385684),
#  ('c', 0.00025170072355431064),
#  ('c++', 0.00025170072355431064),
#  ('r', 0.00016760169934577053),
#  ('machine-learning', 0.00016564418593243723),
#  ('ios', 9.895662525302128e-05),
#  ('objective-c', 9.019307072781168e-05),
#  ('android', 8.558990732281467e-05),
#  ('github', 7.216060662788767e-05),
#  ('go', 7.180553173480832e-05),
#  ('powershell', 6.792340205251358e-05),
#  ('eclipse', 5.605802229704869e-05),
#  ('qt', 2.8711390806039782e-05),
#  ('embedded', 2.8711390806039782e-05),
#  ('swift', 2.795344684741188e-05),
#  ('iphone', 2.795344684741188e-05),
#  ('xcode', 2.795344684741188e-05),
#  ('matlab', 1.9118243301219333e-05),
#  ('android-studio', 9.763208697519257e-06),
#  ('scala', 5.095827740019828e-38),
#  ('hadoop', 4.3550863959755164e-38),
#  ('apache-spark', 4.3550863959755164e-38),
#  ('haskell', 2.3482141248400767e-38),
#  ('excel', 6.869562052796331e-40),
#  ('excel-vba', 6.869562052796331e-40),
#  ('vba', 6.869562052796331e-40),
#  ('tdd', 4.266626453444441e-53),
#  ('agile', 4.266626453444441e-53),
#  ('testing', 4.266626453444441e-53),
#  ('selenium', 4.266626453444441e-53),
#  ('regex', 4.266626453444441e-53),
#  ('perl', 4.266626453444441e-53)]

# %%
draw(G, pos, nx.eigenvector_centrality(G), 'Closeness Centrality')

# %%
popular_languages = ['c','c++','c#','java','python','javascript']
popular_language_nodes = []
for language in popular_languages:
    node_neighbors = G.neighbors(language)
    popular_language_nodes.extend(node_neighbors)

# %%
popular_languages_graph = G.subgraph(set(popular_language_nodes))

# %%
show_graph(popular_languages_graph)

# %%
#spark.stop()
